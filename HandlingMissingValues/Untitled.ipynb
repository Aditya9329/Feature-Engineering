# %%
import pandas as pd 
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
df = pd.DataFrame({'A':[1,2,np.nan,3]
                  ,
                  'B':[2,4,np.nan,8],
                  'C':[1,np.nan,np.nan,7]})

# %%
df
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  NaN  NaN  NaN
# 3  3.0  8.0  7.0

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False   True
# 2   True   True   True
# 3  False  False  False

# %%
# df[df['A'].isnull()] = 0

# %%
df['A']
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  NaN  NaN  NaN
# 3  3.0  8.0  7.0

# %%
df['A'][df['A'].isnull()] = 0 ///making this particular column as series

# %%
df['B'][df['B'].isnull()] = 6

# %%
df
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  0.0  6.0  NaN
# 3  3.0  8.0  7.0

# %%
df['C'][df['C'].isnull()] = 4.5

# %%
df
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  4.5
# 2  0.0  6.0  4.5
# 3  3.0  8.0  7.0

# %%
l = [1,2,3,4,5,6,7,8]

# %%
np.random.sample(l)
# Out:
# array([[[[[[[[9.19264334e-01, 6.98421971e-01, 6.65053070e-01, ...,
#               6.03348678e-01, 8.91496021e-01, 8.64787940e-03],
#              [6.80573198e-02, 1.07641351e-01, 7.55791619e-01, ...,
#               6.05276353e-02, 3.21037483e-01, 9.70663330e-01],
#              [5.75577288e-01, 8.00445391e-01, 1.07468534e-01, ...,
#               7.98385291e-01, 7.49865359e-01, 2.12506393e-01],
#              ...,
#              [5.01447292e-01, 9.59105894e-01, 3.63005179e-01, ...,
#               6.64608115e-01, 6.96044083e-01, 9.54121390e-01],
#              [4.78440738e-01, 3.78141031e-01, 8.77105499e-01, ...,
#               4.94224671e-01, 6.47195400e-01, 6.88539628e-01],
#              [3.12476379e-01, 8.89506082e-01, 9.85493053e-02, ...,
#               7.98849550e-01, 9.83332503e-01, 2.17757638e-01]],
#
#             [[5.32578863e-01, 6.10065392e-01, 5.52389678e-01, ...,
#               3.51181267e-01, 8.47721356e-01, 3.25304416e-01],
# ...

# %%
df2 = pd.DataFrame({'A':[1,2,np.nan,3]
                  ,
                  'B':[2,4,np.nan,8],
                  'C':[1,np.nan,np.nan,7]})

# %%
df2
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  NaN  NaN  NaN
# 3  3.0  8.0  7.0

# %%
df['A'].values
# Out:
# array([1., 2., 0., 3.])

# %%
df['A'][df['A'].isnull()]
# Out:
# Series([], Name: A, dtype: float64)

# %%
df2
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  NaN  NaN  NaN
# 3  3.0  8.0  7.0

# %%
t = df2['A'].sample()

# %%
t
# Out:
# 3    3.0
# Name: A, dtype: float64

# %%
df2['A'][df2['A'].isnull()] = 3.0

# %%
df2
# Out:
#      A    B    C
# 0  1.0  2.0  1.0
# 1  2.0  4.0  NaN
# 2  3.0  NaN  NaN
# 3  3.0  8.0  7.0
